# %%
import pandas as pd

# Load the UFC data
df = pd.read_csv('../data/data.csv')

# Display the first 5 rows
df.head()
# Out:
#        R_fighter          B_fighter        Referee        date  \
# 0   Adrian Yanez      Gustavo Lopez  Chris Tognoni  2021-03-20
# 1   Trevin Giles      Roman Dolidze      Herb Dean  2021-03-20
# 2    Tai Tuivasa    Harry Hunsucker      Herb Dean  2021-03-20
# 3  Cheyanne Buys  Montserrat Conejo     Mark Smith  2021-03-20
# 4  Marion Reneau      Macy Chiasson     Mark Smith  2021-03-20
#
#                  location Winner  title_bout       weight_class  B_avg_KD  \
# 0  Las Vegas, Nevada, USA    Red       False       Bantamweight     0.000
# 1  Las Vegas, Nevada, USA    Red       False       Middleweight     0.500
# 2  Las Vegas, Nevada, USA    Red       False        Heavyweight       NaN
# 3  Las Vegas, Nevada, USA   Blue       False   WomenStrawweight       NaN
# 4  Las Vegas, Nevada, USA   Blue       False  WomenBantamweight     0.125
#
#    B_avg_opp_KD  ...  R_win_by_Decision_Unanimous  R_win_by_KO/TKO  \
# 0           0.0  ...                            0                1
# 1           0.0  ...                            0                3
# 2           NaN  ...                            1                3
# 3           NaN  ...                            0                0
# 4           0.0  ...                            1                2
#
#    R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_Stance  R_Height_cms  \
# 0                    0                             0  Orthodox        170.18
# 1                    0                             0  Orthodox        182.88
# 2                    0                             0  Southpaw        187.96
# 3                    0                             0    Switch        160.02
# 4                    2                             0  Orthodox        167.64
#
#    R_Reach_cms  R_Weight_lbs  B_age  R_age
# 0       177.80         135.0   31.0   27.0
# 1       187.96         185.0   32.0   28.0
# 2       190.50         264.0   32.0   28.0
# 3       160.02         115.0   28.0   25.0
# 4       172.72         135.0   29.0   43.0
#
# [5 rows x 144 columns]

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'Referee', 'date', 'location', 'Winner',
#        'title_bout', 'weight_class', 'B_avg_KD', 'B_avg_opp_KD',
#        ...
#        'R_win_by_Decision_Unanimous', 'R_win_by_KO/TKO', 'R_win_by_Submission',
#        'R_win_by_TKO_Doctor_Stoppage', 'R_Stance', 'R_Height_cms',
#        'R_Reach_cms', 'R_Weight_lbs', 'B_age', 'R_age'],
#       dtype='object', length=144)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6012 entries, 0 to 6011
# Columns: 144 entries, R_fighter to R_age
# dtypes: bool(1), float64(106), int64(28), object(9)
# memory usage: 6.6+ MB

# %%
df.describe()
# Out:
#           B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  \
# count  4585.000000   4585.000000        4585.000000            4585.000000
# mean      0.247476      0.176818           0.453310               0.434290
# std       0.378509      0.324633           0.130458               0.132618
# min       0.000000      0.000000           0.000000               0.000000
# 25%       0.000000      0.000000           0.376489               0.351045
# 50%       0.015625      0.000000           0.450000               0.427500
# 75%       0.500000      0.250000           0.527500               0.510000
# max       5.000000      3.000000           1.000000               1.000000
#
#        B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  B_avg_opp_SUB_ATT  \
# count   4585.000000       4585.000000    4585.000000        4585.000000
# mean       0.292650          0.268742       0.478884           0.409276
# std        0.273628          0.267178       0.724229           0.653826
# min        0.000000          0.000000       0.000000           0.000000
# 25%        0.031250          0.033203       0.000000           0.000000
# 50%        0.250000          0.200000       0.148468           0.098389
# 75%        0.500000          0.422812       0.750000           0.531250
# max        1.000000          1.000000       8.000000           7.000000
#
#         B_avg_REV  B_avg_opp_REV  ...  R_win_by_Decision_Split  \
# count  4585.00000    4585.000000  ...              6012.000000
# mean      0.15673       0.141306  ...                 0.306886
# std       0.34199       0.322623  ...                 0.619485
# min       0.00000       0.000000  ...                 0.000000
# 25%       0.00000       0.000000  ...                 0.000000
# 50%       0.00000       0.000000  ...                 0.000000
# 75%       0.12500       0.125000  ...                 0.000000
# max       4.00000       3.000000  ...                 5.000000
#
#        R_win_by_Decision_Unanimous  R_win_by_KO/TKO  R_win_by_Submission  \
# count                  6012.000000      6012.000000          6012.000000
# mean                      1.251331         1.297572             0.796241
# std                       1.681376         1.859955             1.355801
# min                       0.000000         0.000000             0.000000
# 25%                       0.000000         0.000000             0.000000
# 50%                       1.000000         1.000000             0.000000
# 75%                       2.000000         2.000000             1.000000
# max                      10.000000        11.000000            13.000000
#
#        R_win_by_TKO_Doctor_Stoppage  R_Height_cms  R_Reach_cms  R_Weight_lbs  \
# count                   6012.000000   6008.000000  5606.000000   6010.000000
# mean                       0.069195    178.991788   183.562347    170.686356
# std                        0.273980      8.812985    10.585313     35.724626
# min                        0.000000    152.400000   152.400000    115.000000
# 25%                        0.000000    172.720000   177.800000    145.000000
# 50%                        0.000000    180.340000   182.880000    170.000000
# 75%                        0.000000    185.420000   190.500000    185.000000
# max                        2.000000    210.820000   213.360000    345.000000
#
#              B_age        R_age
# count  5840.000000  5949.000000
# mean     29.293151    29.598252
# std       4.063297     4.167755
# min      18.000000    19.000000
# 25%      26.000000    27.000000
# 50%      29.000000    29.000000
# 75%      32.000000    32.000000
# max      51.000000    47.000000
#
# [8 rows x 134 columns]

# %%
df['Winner'].value_counts(dropna=False)
# Out:
# Winner
# Red     3979
# Blue    1923
# Draw     110
# Name: count, dtype: int64

# %%
# Only keep rows with a clear winner (not draw or NC)
df_clean = df[df['Winner'].isin(['Red', 'Blue'])].copy()

# Create a binary column: 1 if Red won, 0 if Blue won
df_clean['R_winner'] = df_clean['Winner'].apply(lambda x: 1 if x == 'Red' else 0)

# %%
# Get all columns that start with 'R_' (Red fighter stats)
red_cols = [col for col in df_clean.columns if col.startswith('R_')]

# View the first few rows of those columns
df_clean[red_cols].head()
# Out:
#        R_fighter  R_avg_KD  R_avg_opp_KD  R_avg_SIG_STR_pct  \
# 0   Adrian Yanez  1.000000      0.000000           0.500000
# 1   Trevin Giles  1.031250      0.062500           0.576875
# 2    Tai Tuivasa  0.546875      0.187500           0.538906
# 3  Cheyanne Buys       NaN           NaN                NaN
# 4  Marion Reneau  0.000000      0.000977           0.403076
#
#    R_avg_opp_SIG_STR_pct  R_avg_TD_pct  R_avg_opp_TD_pct  R_avg_SUB_ATT  \
# 0               0.460000      0.000000           0.00000       0.000000
# 1               0.381250      0.406250           0.11625       0.250000
# 2               0.598594      0.000000           0.31250       0.000000
# 3                    NaN           NaN               NaN            NaN
# 4               0.554961      0.511719           0.62875       0.231445
#
#    R_avg_opp_SUB_ATT  R_avg_REV  ...  R_win_by_Decision_Unanimous  \
# 0            0.00000    0.00000  ...                            0
# 1            1.18750    0.37500  ...                            0
# 2            0.25000    0.00000  ...                            1
# 3                NaN        NaN  ...                            0
# 4            0.03125    0.03125  ...                            1
#
#    R_win_by_KO/TKO  R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  \
# 0                1                    0                             0
# 1                3                    0                             0
# 2                3                    0                             0
# 3                0                    0                             0
# 4                2                    2                             0
#
#    R_Stance  R_Height_cms  R_Reach_cms  R_Weight_lbs  R_age  R_winner
# 0  Orthodox        170.18       177.80         135.0   27.0         1
# 1  Orthodox        182.88       187.96         185.0   28.0         1
# 2  Southpaw        187.96       190.50         264.0   28.0         1
# 3    Switch        160.02       160.02         115.0   25.0         0
# 4  Orthodox        167.64       172.72         135.0   43.0         0
#
# [5 rows x 70 columns]

# %%
# List all red corner columns that start with 'R_'
[col for col in df_clean.columns if col.startswith('R_')]
# Out:
# ['R_fighter',
#  'R_avg_KD',
#  'R_avg_opp_KD',
#  'R_avg_SIG_STR_pct',
#  'R_avg_opp_SIG_STR_pct',
#  'R_avg_TD_pct',
#  'R_avg_opp_TD_pct',
#  'R_avg_SUB_ATT',
#  'R_avg_opp_SUB_ATT',
#  'R_avg_REV',
#  'R_avg_opp_REV',
#  'R_avg_SIG_STR_att',
#  'R_avg_SIG_STR_landed',
#  'R_avg_opp_SIG_STR_att',
#  'R_avg_opp_SIG_STR_landed',
#  'R_avg_TOTAL_STR_att',
#  'R_avg_TOTAL_STR_landed',
#  'R_avg_opp_TOTAL_STR_att',
#  'R_avg_opp_TOTAL_STR_landed',
#  'R_avg_TD_att',
#  'R_avg_TD_landed',
#  'R_avg_opp_TD_att',
#  'R_avg_opp_TD_landed',
#  'R_avg_HEAD_att',
#  'R_avg_HEAD_landed',
#  'R_avg_opp_HEAD_att',
#  'R_avg_opp_HEAD_landed',
#  'R_avg_BODY_att',
#  'R_avg_BODY_landed',
#  'R_avg_opp_BODY_att',
#  'R_avg_opp_BODY_landed',
#  'R_avg_LEG_att',
#  'R_avg_LEG_landed',
#  'R_avg_opp_LEG_att',
#  'R_avg_opp_LEG_landed',
#  'R_avg_DISTANCE_att',
#  'R_avg_DISTANCE_landed',
#  'R_avg_opp_DISTANCE_att',
#  'R_avg_opp_DISTANCE_landed',
#  'R_avg_CLINCH_att',
#  'R_avg_CLINCH_landed',
#  'R_avg_opp_CLINCH_att',
#  'R_avg_opp_CLINCH_landed',
#  'R_avg_GROUND_att',
#  'R_avg_GROUND_landed',
#  'R_avg_opp_GROUND_att',
#  'R_avg_opp_GROUND_landed',
#  'R_avg_CTRL_time(seconds)',
#  'R_avg_opp_CTRL_time(seconds)',
#  'R_total_time_fought(seconds)',
#  'R_total_rounds_fought',
#  'R_total_title_bouts',
#  'R_current_win_streak',
#  'R_current_lose_streak',
#  'R_longest_win_streak',
#  'R_wins',
#  'R_losses',
#  'R_draw',
#  'R_win_by_Decision_Majority',
#  'R_win_by_Decision_Split',
#  'R_win_by_Decision_Unanimous',
#  'R_win_by_KO/TKO',
#  'R_win_by_Submission',
#  'R_win_by_TKO_Doctor_Stoppage',
#  'R_Stance',
#  'R_Height_cms',
#  'R_Reach_cms',
#  'R_Weight_lbs',
#  'R_age',
#  'R_winner']

# %%
# Only keep rows where the fight had a clear winner (no draws/NC)
df_fights = df[df['Winner'].isin(['Red', 'Blue'])].copy()

# Create two new dataframes: one for each fighter
red_fighters = df_fights.copy()
red_fighters['fighter'] = red_fighters['R_fighter']
red_fighters['won'] = red_fighters['Winner'] == 'Red'

blue_fighters = df_fights.copy()
blue_fighters['fighter'] = blue_fighters['B_fighter']
blue_fighters['won'] = blue_fighters['Winner'] == 'Blue'

# %%
# Only keep fights with a clear winner
df_fights = df[df['Winner'].isin(['Red', 'Blue'])].copy()

# %%
# Create red fighter dataset
red = df_fights[[col for col in df_fights.columns if col.startswith('R_')]].copy()
red.columns = [col.replace('R_', '') for col in red.columns]
red['won'] = df_fights['Winner'] == 'Red'
red['fighter'] = df_fights['R_fighter']

# Create blue fighter dataset
blue = df_fights[[col for col in df_fights.columns if col.startswith('B_')]].copy()
blue.columns = [col.replace('B_', '') for col in blue.columns]
blue['won'] = df_fights['Winner'] == 'Blue'
blue['fighter'] = df_fights['B_fighter']

# %%
# Stack them together
df_fighter_stats = pd.concat([red, blue], ignore_index=True)

# %%
df_fighter_stats.info()
df_fighter_stats.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11804 entries, 0 to 11803
# Data columns (total 82 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   fighter                     11804 non-null  object
#  1   avg_KD                      9707 non-null   float64
#  2   avg_opp_KD                  9707 non-null   float64
#  3   avg_SIG_STpct               5200 non-null   float64
#  4   avg_opp_SIG_STpct           5200 non-null   float64
#  5   avg_TD_pct                  9707 non-null   float64
#  6   avg_opp_TD_pct              9707 non-null   float64
#  7   avg_SUB_ATT                 5200 non-null   float64
#  8   avg_opp_SUB_ATT             5200 non-null   float64
#  9   avg_REV                     9707 non-null   float64
#  10  avg_opp_REV                 9707 non-null   float64
#  11  avg_SIG_STatt               5200 non-null   float64
#  12  avg_SIG_STlanded            5200 non-null   float64
#  13  avg_opp_SIG_STatt           5200 non-null   float64
#  14  avg_opp_SIG_STlanded        5200 non-null   float64
#  15  avg_TOTAL_STatt             5200 non-null   float64
#  16  avg_TOTAL_STlanded          5200 non-null   float64
#  17  avg_opp_TOTAL_STatt         5200 non-null   float64
#  18  avg_opp_TOTAL_STlanded      5200 non-null   float64
#  19  avg_TD_att                  9707 non-null   float64
#  20  avg_TD_landed               9707 non-null   float64
#  21  avg_opp_TD_att              9707 non-null   float64
#  22  avg_opp_TD_landed           9707 non-null   float64
#  23  avg_HEAD_att                9707 non-null   float64
#  24  avg_HEAD_landed             9707 non-null   float64
#  25  avg_opp_HEAD_att            9707 non-null   float64
#  26  avg_opp_HEAD_landed         9707 non-null   float64
#  27  avg_BODY_att                9707 non-null   float64
#  28  avg_BODY_landed             9707 non-null   float64
#  29  avg_opp_BODY_att            9707 non-null   float64
#  30  avg_opp_BODY_landed         9707 non-null   float64
#  31  avg_LEG_att                 9707 non-null   float64
#  32  avg_LEG_landed              9707 non-null   float64
#  33  avg_opp_LEG_att             9707 non-null   float64
#  34  avg_opp_LEG_landed          9707 non-null   float64
#  35  avg_DISTANCE_att            9707 non-null   float64
#  36  avg_DISTANCE_landed         9707 non-null   float64
#  37  avg_opp_DISTANCE_att        9707 non-null   float64
#  38  avg_opp_DISTANCE_landed     9707 non-null   float64
#  39  avg_CLINCH_att              9707 non-null   float64
#  40  avg_CLINCH_landed           9707 non-null   float64
#  41  avg_opp_CLINCH_att          9707 non-null   float64
#  42  avg_opp_CLINCH_landed       9707 non-null   float64
#  43  avg_GROUND_att              9707 non-null   float64
#  44  avg_GROUND_landed           9707 non-null   float64
#  45  avg_opp_GROUND_att          9707 non-null   float64
#  46  avg_opp_GROUND_landed       9707 non-null   float64
#  47  avg_CTRL_time(seconds)      9707 non-null   float64
#  48  avg_opp_CTRL_time(seconds)  9707 non-null   float64
#  49  total_time_fought(seconds)  9707 non-null   float64
#  50  total_rounds_fought         11804 non-null  int64
#  51  total_title_bouts           11804 non-null  int64
#  52  current_win_streak          11804 non-null  int64
#  53  current_lose_streak         11804 non-null  int64
#  54  longest_win_streak          11804 non-null  int64
#  55  wins                        11804 non-null  int64
#  56  losses                      11804 non-null  int64
#  57  draw                        11804 non-null  int64
#  58  win_by_Decision_Majority    11804 non-null  int64
#  59  win_by_Decision_Split       11804 non-null  int64
#  60  win_by_Decision_Unanimous   11804 non-null  int64
#  61  win_by_KO/TKO               11804 non-null  int64
#  62  win_by_Submission           11804 non-null  int64
#  63  win_by_TKO_Doctor_Stoppage  11804 non-null  int64
#  64  Stance                      11714 non-null  object
#  65  Height_cms                  11790 non-null  float64
#  66  Reach_cms                   10533 non-null  float64
#  67  Weight_lbs                  11794 non-null  float64
#  68  age                         11572 non-null  float64
#  69  won                         11804 non-null  bool
#  70  avg_SIG_STR_pct             4507 non-null   float64
#  71  avg_opp_SIG_STR_pct         4507 non-null   float64
#  72  avg_SUATT                   4507 non-null   float64
#  73  avg_opp_SUATT               4507 non-null   float64
#  74  avg_SIG_STR_att             4507 non-null   float64
#  75  avg_SIG_STR_landed          4507 non-null   float64
#  76  avg_opp_SIG_STR_att         4507 non-null   float64
#  77  avg_opp_SIG_STR_landed      4507 non-null   float64
#  78  avg_TOTAL_STR_att           4507 non-null   float64
#  79  avg_TOTAL_STR_landed        4507 non-null   float64
#  80  avg_opp_TOTAL_STR_att       4507 non-null   float64
#  81  avg_opp_TOTAL_STR_landed    4507 non-null   float64
# dtypes: bool(1), float64(65), int64(14), object(2)
# memory usage: 7.3+ MB
#          fighter    avg_KD  avg_opp_KD  avg_SIG_STpct  avg_opp_SIG_STpct  \
# 0   Adrian Yanez  1.000000    0.000000       0.500000           0.460000
# 1   Trevin Giles  1.031250    0.062500       0.576875           0.381250
# 2    Tai Tuivasa  0.546875    0.187500       0.538906           0.598594
# 3  Cheyanne Buys       NaN         NaN            NaN                NaN
# 4  Marion Reneau  0.000000    0.000977       0.403076           0.554961
#
#    avg_TD_pct  avg_opp_TD_pct  avg_SUB_ATT  avg_opp_SUB_ATT  avg_REV  ...  \
# 0    0.000000         0.00000     0.000000          0.00000  0.00000  ...
# 1    0.406250         0.11625     0.250000          1.18750  0.37500  ...
# 2    0.000000         0.31250     0.000000          0.25000  0.00000  ...
# 3         NaN             NaN          NaN              NaN      NaN  ...
# 4    0.511719         0.62875     0.231445          0.03125  0.03125  ...
#
#    avg_SUATT  avg_opp_SUATT  avg_SIG_STR_att  avg_SIG_STR_landed  \
# 0        NaN            NaN              NaN                 NaN
# 1        NaN            NaN              NaN                 NaN
# 2        NaN            NaN              NaN                 NaN
# 3        NaN            NaN              NaN                 NaN
# 4        NaN            NaN              NaN                 NaN
#
#    avg_opp_SIG_STR_att  avg_opp_SIG_STR_landed  avg_TOTAL_STR_att  \
# 0                  NaN                     NaN                NaN
# 1                  NaN                     NaN                NaN
# 2                  NaN                     NaN                NaN
# 3                  NaN                     NaN                NaN
# 4                  NaN                     NaN                NaN
#
#    avg_TOTAL_STR_landed  avg_opp_TOTAL_STR_att  avg_opp_TOTAL_STR_landed
# 0                   NaN                    NaN                       NaN
# 1                   NaN                    NaN                       NaN
# 2                   NaN                    NaN                       NaN
# 3                   NaN                    NaN                       NaN
# 4                   NaN                    NaN                       NaN
#
# [5 rows x 82 columns]

# %%
# Get numeric columns only
numeric_cols = df_fighter_stats.select_dtypes(include='number').drop(columns=['won']).columns

# Add 'won' back in for correlation
corr_df = df_fighter_stats[numeric_cols.tolist() + ['won']]

# Get correlation with 'won'
correlations = corr_df.corr()['won'].sort_values(ascending=False)
correlations
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Get numeric columns only
# ----> 2 numeric_cols = df_fighter_stats.select_dtypes(include='number').drop(columns=['won']).columns
#       4 # Add 'won' back in for correlation
#       5 corr_df = df_fighter_stats[numeric_cols.tolist() + ['won']]
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['won'] not found in axis"

# %%
'winner' in df_fighter_stats.columns
'won' in df_fighter_stats.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 'winner' in df_fighter_stats.columns
#       2 'won' in df_fighter_stats.columns
#
# NameError: name 'df_fighter_stats' is not defined

# %%
# Step 1: Keep only fights with a clear winner
df_fights = df[df['Winner'].isin(['Red', 'Blue'])].copy()

# Step 2: Create red fighter DataFrame
red = df_fights[[col for col in df_fights.columns if col.startswith('R_')]].copy()
red.columns = [col.replace('R_', '') for col in red.columns]
red['won'] = df_fights['Winner'] == 'Red'
red['fighter'] = df_fights['R_fighter']

# Step 3: Create blue fighter DataFrame
blue = df_fights[[col for col in df_fights.columns if col.startswith('B_')]].copy()
blue.columns = [col.replace('B_', '') for col in blue.columns]
blue['won'] = df_fights['Winner'] == 'Blue'
blue['fighter'] = df_fights['B_fighter']

# Step 4: Combine both into one fighter-level dataset
df_fighter_stats = pd.concat([red, blue], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Step 1: Keep only fights with a clear winner
# ----> 2 df_fights = df[df['Winner'].isin(['Red', 'Blue'])].copy()
#       4 # Step 2: Create red fighter DataFrame
#       5 red = df_fights[[col for col in df_fights.columns if col.startswith('R_')]].copy()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# Re-load the original UFC dataset
df = pd.read_csv('../data/data.csv')

# %%
# Step 1: Keep only fights with a clear winner
df_fights = df[df['Winner'].isin(['Red', 'Blue'])].copy()

# Step 2: Create red fighter DataFrame
red = df_fights[[col for col in df_fights.columns if col.startswith('R_')]].copy()
red.columns = [col.replace('R_', '') for col in red.columns]
red['won'] = df_fights['Winner'] == 'Red'
red['fighter'] = df_fights['R_fighter']

# Step 3: Create blue fighter DataFrame
blue = df_fights[[col for col in df_fights.columns if col.startswith('B_')]].copy()
blue.columns = [col.replace('B_', '') for col in blue.columns]
blue['won'] = df_fights['Winner'] == 'Blue'
blue['fighter'] = df_fights['B_fighter']

# Step 4: Combine both into one fighter-level dataset
df_fighter_stats = pd.concat([red, blue], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'R_fighter'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 8
#       6 red.columns = [col.replace('R_', '') for col in red.columns]
#       7 red['won'] = df_fights['Winner'] == 'Red'
# ----> 8 red['fighter'] = df_fights['R_fighter']
#      10 # Step 3: Create blue fighter DataFrame
#      11 blue = df_fights[[col for col in df_fights.columns if col.startswith('B_')]].copy()
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'R_fighter'

# %%
df.columns.to_list()
# Out:
# ['≤R_fighter',
#  'B_fighter',
#  'Referee',
#  'date',
#  'location',
#  'Winner',
#  'title_bout',
#  'weight_class',
#  'B_avg_KD',
#  'B_avg_opp_KD',
#  'B_avg_SIG_STR_pct',
#  'B_avg_opp_SIG_STR_pct',
#  'B_avg_TD_pct',
#  'B_avg_opp_TD_pct',
#  'B_avg_SUB_ATT',
#  'B_avg_opp_SUB_ATT',
#  'B_avg_REV',
#  'B_avg_opp_REV',
#  'B_avg_SIG_STR_att',
#  'B_avg_SIG_STR_landed',
#  'B_avg_opp_SIG_STR_att',
#  'B_avg_opp_SIG_STR_landed',
#  'B_avg_TOTAL_STR_att',
#  'B_avg_TOTAL_STR_landed',
#  'B_avg_opp_TOTAL_STR_att',
#  'B_avg_opp_TOTAL_STR_landed',
#  'B_avg_TD_att',
#  'B_avg_TD_landed',
#  'B_avg_opp_TD_att',
#  'B_avg_opp_TD_landed',
#  'B_avg_HEAD_att',
#  'B_avg_HEAD_landed',
#  'B_avg_opp_HEAD_att',
#  'B_avg_opp_HEAD_landed',
#  'B_avg_BODY_att',
#  'B_avg_BODY_landed',
#  'B_avg_opp_BODY_att',
#  'B_avg_opp_BODY_landed',
#  'B_avg_LEG_att',
#  'B_avg_LEG_landed',
#  'B_avg_opp_LEG_att',
#  'B_avg_opp_LEG_landed',
#  'B_avg_DISTANCE_att',
#  'B_avg_DISTANCE_landed',
#  'B_avg_opp_DISTANCE_att',
#  'B_avg_opp_DISTANCE_landed',
#  'B_avg_CLINCH_att',
#  'B_avg_CLINCH_landed',
#  'B_avg_opp_CLINCH_att',
#  'B_avg_opp_CLINCH_landed',
#  'B_avg_GROUND_att',
#  'B_avg_GROUND_landed',
#  'B_avg_opp_GROUND_att',
#  'B_avg_opp_GROUND_landed',
#  'B_avg_CTRL_time(seconds)',
#  'B_avg_opp_CTRL_time(seconds)',
#  'B_total_time_fought(seconds)',
#  'B_total_rounds_fought',
#  'B_total_title_bouts',
#  'B_current_win_streak',
#  'B_current_lose_streak',
#  'B_longest_win_streak',
#  'B_wins',
#  'B_losses',
#  'B_draw',
#  'B_win_by_Decision_Majority',
#  'B_win_by_Decision_Split',
#  'B_win_by_Decision_Unanimous',
#  'B_win_by_KO/TKO',
#  'B_win_by_Submission',
#  'B_win_by_TKO_Doctor_Stoppage',
#  'B_Stance',
#  'B_Height_cms',
#  'B_Reach_cms',
#  'B_Weight_lbs',
#  'R_avg_KD',
#  'R_avg_opp_KD',
#  'R_avg_SIG_STR_pct',
#  'R_avg_opp_SIG_STR_pct',
#  'R_avg_TD_pct',
#  'R_avg_opp_TD_pct',
#  'R_avg_SUB_ATT',
#  'R_avg_opp_SUB_ATT',
#  'R_avg_REV',
#  'R_avg_opp_REV',
#  'R_avg_SIG_STR_att',
#  'R_avg_SIG_STR_landed',
#  'R_avg_opp_SIG_STR_att',
#  'R_avg_opp_SIG_STR_landed',
#  'R_avg_TOTAL_STR_att',
#  'R_avg_TOTAL_STR_landed',
#  'R_avg_opp_TOTAL_STR_att',
#  'R_avg_opp_TOTAL_STR_landed',
#  'R_avg_TD_att',
#  'R_avg_TD_landed',
#  'R_avg_opp_TD_att',
#  'R_avg_opp_TD_landed',
#  'R_avg_HEAD_att',
#  'R_avg_HEAD_landed',
#  'R_avg_opp_HEAD_att',
#  'R_avg_opp_HEAD_landed',
#  'R_avg_BODY_att',
#  'R_avg_BODY_landed',
#  'R_avg_opp_BODY_att',
#  'R_avg_opp_BODY_landed',
#  'R_avg_LEG_att',
#  'R_avg_LEG_landed',
#  'R_avg_opp_LEG_att',
#  'R_avg_opp_LEG_landed',
#  'R_avg_DISTANCE_att',
#  'R_avg_DISTANCE_landed',
#  'R_avg_opp_DISTANCE_att',
#  'R_avg_opp_DISTANCE_landed',
#  'R_avg_CLINCH_att',
#  'R_avg_CLINCH_landed',
#  'R_avg_opp_CLINCH_att',
#  'R_avg_opp_CLINCH_landed',
#  'R_avg_GROUND_att',
#  'R_avg_GROUND_landed',
#  'R_avg_opp_GROUND_att',
#  'R_avg_opp_GROUND_landed',
#  'R_avg_CTRL_time(seconds)',
#  'R_avg_opp_CTRL_time(seconds)',
#  'R_total_time_fought(seconds)',
#  'R_total_rounds_fought',
#  'R_total_title_bouts',
#  'R_current_win_streak',
#  'R_current_lose_streak',
#  'R_longest_win_streak',
#  'R_wins',
#  'R_losses',
#  'R_draw',
#  'R_win_by_Decision_Majority',
#  'R_win_by_Decision_Split',
#  'R_win_by_Decision_Unanimous',
#  'R_win_by_KO/TKO',
#  'R_win_by_Submission',
#  'R_win_by_TKO_Doctor_Stoppage',
#  'R_Stance',
#  'R_Height_cms',
#  'R_Reach_cms',
#  'R_Weight_lbs',
#  'B_age',
#  'R_age']

# %%
# Step 1: Keep fights with clear winners
df_fights = df[df['Winner'].isin(['Red', 'Blue'])].copy()

# Step 2: Create red fighter DataFrame
red = df_fights[[col for col in df_fights.columns if col.startswith('R_')]].copy()
red['won'] = df_fights['Winner'] == 'Red'
red['fighter'] = df_fights['R_fighter']
red.columns = [col.replace('R_', '') for col in red.columns]

# Step 3: Create blue fighter DataFrame
blue = df_fights[[col for col in df_fights.columns if col.startswith('B_')]].copy()
blue['won'] = df_fights['Winner'] == 'Blue'
blue['fighter'] = df_fights['B_fighter']
blue.columns = [col.replace('B_', '') for col in blue.columns]

# Step 4: Combine red and blue into one fighter-level dataset
df_fighter_stats = pd.concat([red, blue], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'R_fighter'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 7
#       5 red = df_fights[[col for col in df_fights.columns if col.startswith('R_')]].copy()
#       6 red['won'] = df_fights['Winner'] == 'Red'
# ----> 7 red['fighter'] = df_fights['R_fighter']
#       8 red.columns = [col.replace('R_', '') for col in red.columns]
#      10 # Step 3: Create blue fighter DataFrame
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'R_fighter'

# %%
df.columns.to_list()
# Out:
# ['≤R_fighter',
#  'B_fighter',
#  'Referee',
#  'date',
#  'location',
#  'Winner',
#  'title_bout',
#  'weight_class',
#  'B_avg_KD',
#  'B_avg_opp_KD',
#  'B_avg_SIG_STR_pct',
#  'B_avg_opp_SIG_STR_pct',
#  'B_avg_TD_pct',
#  'B_avg_opp_TD_pct',
#  'B_avg_SUB_ATT',
#  'B_avg_opp_SUB_ATT',
#  'B_avg_REV',
#  'B_avg_opp_REV',
#  'B_avg_SIG_STR_att',
#  'B_avg_SIG_STR_landed',
#  'B_avg_opp_SIG_STR_att',
#  'B_avg_opp_SIG_STR_landed',
#  'B_avg_TOTAL_STR_att',
#  'B_avg_TOTAL_STR_landed',
#  'B_avg_opp_TOTAL_STR_att',
#  'B_avg_opp_TOTAL_STR_landed',
#  'B_avg_TD_att',
#  'B_avg_TD_landed',
#  'B_avg_opp_TD_att',
#  'B_avg_opp_TD_landed',
#  'B_avg_HEAD_att',
#  'B_avg_HEAD_landed',
#  'B_avg_opp_HEAD_att',
#  'B_avg_opp_HEAD_landed',
#  'B_avg_BODY_att',
#  'B_avg_BODY_landed',
#  'B_avg_opp_BODY_att',
#  'B_avg_opp_BODY_landed',
#  'B_avg_LEG_att',
#  'B_avg_LEG_landed',
#  'B_avg_opp_LEG_att',
#  'B_avg_opp_LEG_landed',
#  'B_avg_DISTANCE_att',
#  'B_avg_DISTANCE_landed',
#  'B_avg_opp_DISTANCE_att',
#  'B_avg_opp_DISTANCE_landed',
#  'B_avg_CLINCH_att',
#  'B_avg_CLINCH_landed',
#  'B_avg_opp_CLINCH_att',
#  'B_avg_opp_CLINCH_landed',
#  'B_avg_GROUND_att',
#  'B_avg_GROUND_landed',
#  'B_avg_opp_GROUND_att',
#  'B_avg_opp_GROUND_landed',
#  'B_avg_CTRL_time(seconds)',
#  'B_avg_opp_CTRL_time(seconds)',
#  'B_total_time_fought(seconds)',
#  'B_total_rounds_fought',
#  'B_total_title_bouts',
#  'B_current_win_streak',
#  'B_current_lose_streak',
#  'B_longest_win_streak',
#  'B_wins',
#  'B_losses',
#  'B_draw',
#  'B_win_by_Decision_Majority',
#  'B_win_by_Decision_Split',
#  'B_win_by_Decision_Unanimous',
#  'B_win_by_KO/TKO',
#  'B_win_by_Submission',
#  'B_win_by_TKO_Doctor_Stoppage',
#  'B_Stance',
#  'B_Height_cms',
#  'B_Reach_cms',
#  'B_Weight_lbs',
#  'R_avg_KD',
#  'R_avg_opp_KD',
#  'R_avg_SIG_STR_pct',
#  'R_avg_opp_SIG_STR_pct',
#  'R_avg_TD_pct',
#  'R_avg_opp_TD_pct',
#  'R_avg_SUB_ATT',
#  'R_avg_opp_SUB_ATT',
#  'R_avg_REV',
#  'R_avg_opp_REV',
#  'R_avg_SIG_STR_att',
#  'R_avg_SIG_STR_landed',
#  'R_avg_opp_SIG_STR_att',
#  'R_avg_opp_SIG_STR_landed',
#  'R_avg_TOTAL_STR_att',
#  'R_avg_TOTAL_STR_landed',
#  'R_avg_opp_TOTAL_STR_att',
#  'R_avg_opp_TOTAL_STR_landed',
#  'R_avg_TD_att',
#  'R_avg_TD_landed',
#  'R_avg_opp_TD_att',
#  'R_avg_opp_TD_landed',
#  'R_avg_HEAD_att',
#  'R_avg_HEAD_landed',
#  'R_avg_opp_HEAD_att',
#  'R_avg_opp_HEAD_landed',
#  'R_avg_BODY_att',
#  'R_avg_BODY_landed',
#  'R_avg_opp_BODY_att',
#  'R_avg_opp_BODY_landed',
#  'R_avg_LEG_att',
#  'R_avg_LEG_landed',
#  'R_avg_opp_LEG_att',
#  'R_avg_opp_LEG_landed',
#  'R_avg_DISTANCE_att',
#  'R_avg_DISTANCE_landed',
#  'R_avg_opp_DISTANCE_att',
#  'R_avg_opp_DISTANCE_landed',
#  'R_avg_CLINCH_att',
#  'R_avg_CLINCH_landed',
#  'R_avg_opp_CLINCH_att',
#  'R_avg_opp_CLINCH_landed',
#  'R_avg_GROUND_att',
#  'R_avg_GROUND_landed',
#  'R_avg_opp_GROUND_att',
#  'R_avg_opp_GROUND_landed',
#  'R_avg_CTRL_time(seconds)',
#  'R_avg_opp_CTRL_time(seconds)',
#  'R_total_time_fought(seconds)',
#  'R_total_rounds_fought',
#  'R_total_title_bouts',
#  'R_current_win_streak',
#  'R_current_lose_streak',
#  'R_longest_win_streak',
#  'R_wins',
#  'R_losses',
#  'R_draw',
#  'R_win_by_Decision_Majority',
#  'R_win_by_Decision_Split',
#  'R_win_by_Decision_Unanimous',
#  'R_win_by_KO/TKO',
#  'R_win_by_Submission',
#  'R_win_by_TKO_Doctor_Stoppage',
#  'R_Stance',
#  'R_Height_cms',
#  'R_Reach_cms',
#  'R_Weight_lbs',
#  'B_age',
#  'R_age']

# %%
# Rename the weird column to 'R_fighter'
df = df.rename(columns={'≤R_fighter': 'R_fighter'})

# %%
# Step 1: Keep fights with clear winners
df_fights = df[df['Winner'].isin(['Red', 'Blue'])].copy()

# Step 2: Create red fighter DataFrame
red = df_fights[[col for col in df_fights.columns if col.startswith('R_')]].copy()
red['won'] = df_fights['Winner'] == 'Red'
red['fighter'] = df_fights['R_fighter']
red.columns = [col.replace('R_', '') for col in red.columns]

# Step 3: Create blue fighter DataFrame
blue = df_fights[[col for col in df_fights.columns if col.startswith('B_')]].copy()
blue['won'] = df_fights['Winner'] == 'Blue'
blue['fighter'] = df_fights['B_fighter']
blue.columns = [col.replace('B_', '') for col in blue.columns]

# Step 4: Combine red and blue into one fighter-level dataset
df_fighter_stats = pd.concat([red, blue], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[9], line 17
#      14 blue.columns = [col.replace('B_', '') for col in blue.columns]
#      16 # Step 4: Combine red and blue into one fighter-level dataset
# ---> 17 df_fighter_stats = pd.concat([red, blue], ignore_index=True)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/reshape/concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)    392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/reshape/concat.py:680, in _Concatenator.get_result(self)
#     678         obj_labels = obj.axes[1 - ax]
#     679         if not new_labels.equals(obj_labels):
# --> 680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
#     684 new_data = concatenate_managers(
#     685     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     686 )
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3885, in Index.get_indexer(self, target, method, limit, tolerance)
#    3882 self._check_indexing_method(method, limit, tolerance)
#    3884 if not self._index_as_unique:
# -> 3885     raise InvalidIndexError(self._requires_unique_msg)
#    3887 if len(target) == 0:
#    3888     return np.array([], dtype=np.intp)
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
print(red.columns[red.columns.duplicated()])
print(blue.columns[blue.columns.duplicated()])
# Out:
# Index(['fighter'], dtype='object')
# Index(['fighter'], dtype='object')

# %%
# Step 1: Get red fighter stats
red = df_fights[[col for col in df_fights.columns if col.startswith('R_')]].copy()
red['won'] = df_fights['Winner'] == 'Red'
red['fighter_name'] = df_fights['R_fighter']  # ✅ rename to something unique
red.columns = [col.replace('R_', '') for col in red.columns]
red = red.loc[:, ~red.columns.duplicated()]  # ✅ remove any accidental duplicates

# Step 2: Get blue fighter stats
blue = df_fights[[col for col in df_fights.columns if col.startswith('B_')]].copy()
blue['won'] = df_fights['Winner'] == 'Blue'
blue['fighter_name'] = df_fights['B_fighter']  # ✅ rename to something unique
blue.columns = [col.replace('B_', '') for col in blue.columns]
blue = blue.loc[:, ~blue.columns.duplicated()]

# Step 3: Combine into one fighter-level dataset
df_fighter_stats = pd.concat([red, blue], ignore_index=True)

# %%
numeric_cols = df_fighter_stats.select_dtypes(include='number').drop(columns=['won']).columns
corr_df = df_fighter_stats[numeric_cols.tolist() + ['won']]
correlations = corr_df.corr()['won'].sort_values(ascending=False)
correlations
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 numeric_cols = df_fighter_stats.select_dtypes(include='number').drop(columns=['won']).columns
#       2 corr_df = df_fighter_stats[numeric_cols.tolist() + ['won']]
#       3 correlations = corr_df.corr()['won'].sort_values(ascending=False)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['won'] not found in axis"

# %%
# Get numeric columns (excluding 'won' if present)
numeric_cols = df_fighter_stats.select_dtypes(include='number').columns.drop('won', errors='ignore')

# Create a new DataFrame for correlation
corr_df = df_fighter_stats[numeric_cols.tolist() + ['won']]

# Get correlation of all stats vs win outcome
correlations = corr_df.corr()['won'].sort_values(ascending=False)
correlations
# Out:
# won                       1.000000
# avg_SIG_STR_landed        0.137753
# avg_SIG_STR_att           0.136412
# avg_TOTAL_STR_att         0.114786
# avg_opp_SIG_STR_att       0.091017
#                             ...
# avg_opp_TOTAL_STlanded   -0.100264
# avg_opp_TOTAL_STatt      -0.107253
# avg_opp_SIG_STatt        -0.119392
# avg_opp_SIG_STlanded     -0.148524
# draw                           NaN
# Name: won, Length: 80, dtype: float64

# %%
df_fighter_stats['weight_class'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'weight_class'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df_fighter_stats['weight_class'].value_counts()
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'weight_class'

# %%
# Red fighter data
red = df_fights[[col for col in df_fights.columns if col.startswith('R_')]].copy()
red['won'] = df_fights['Winner'] == 'Red'
red['fighter_name'] = df_fights['R_fighter']
red['weight_class'] = df_fights['weight_class']  # ✅ Add this line
red.columns = [col.replace('R_', '') for col in red.columns]
red = red.loc[:, ~red.columns.duplicated()]

# Blue fighter data
blue = df_fights[[col for col in df_fights.columns if col.startswith('B_')]].copy()
blue['won'] = df_fights['Winner'] == 'Blue'
blue['fighter_name'] = df_fights['B_fighter']
blue['weight_class'] = df_fights['weight_class']  # ✅ Add this line
blue.columns = [col.replace('B_', '') for col in blue.columns]
blue = blue.loc[:, ~blue.columns.duplicated()]

# %%
df_fighter_stats = pd.concat([red, blue], ignore_index=True)

# %%
df_fighter_stats['weight_class'].value_counts()
# Out:
# weight_class
# Lightweight           2144
# Welterweight          2132
# Middleweight          1606
# Heavyweight           1146
# LightHeavyweight      1118
# Featherweight         1078
# Bantamweight           924
# Flyweight              452
# WomenStrawweight       380
# WomenBantamweight      298
# WomenFlyweight         220
# OpenWeight             172
# CatchWeight            102
# WomenFeatherweight      32
# Name: count, dtype: int64

# %%
def get_weight_class_correlations(df, weight_class_name):
    """
    Returns the top 10 and bottom 10 correlations between fight stats and winning,
    for a specific weight class.
    """
    # Filter for one weight class
    wc_df = df[df['weight_class'] == weight_class_name]
    
    # Only numeric columns (excluding 'won' for now)
    numeric_cols = wc_df.select_dtypes(include='number').columns.drop('won', errors='ignore')
    
    # Prepare a DataFrame for correlation
    corr_df = wc_df[numeric_cols.tolist() + ['won']]
    
    # Calculate correlation with 'won'
    correlations = corr_df.corr()['won'].dropna()
    
    # Get top 10 and bottom 10
    top_10 = correlations.sort_values(ascending=False).head(10)
    bottom_10 = correlations.sort_values(ascending=True).head(10)
    
    return top_10, bottom_10

# %%
top, bottom = get_weight_class_correlations(df_fighter_stats, 'Lightweight')

print("🔝 Top 10 Positive Correlations:")
print(top)

print("\n🔻 Bottom 10 Negative Correlations:")
print(bottom)
# Out:
# 🔝 Top 10 Positive Correlations:
# won                    1.000000
# avg_SUB_ATT            0.157656
# avg_SIG_STR_landed     0.156207
# avg_SIG_STR_att        0.152992
# avg_opp_SUB_ATT        0.136987
# avg_TOTAL_STR_att      0.106301
# avg_GROUND_att         0.104920
# avg_GROUND_landed      0.102964
# avg_opp_SIG_STR_att    0.097563
# avg_TD_landed          0.089752
# Name: won, dtype: float64
#
# 🔻 Bottom 10 Negative Correlations:
# avg_opp_SIG_STlanded   -0.163795
# avg_opp_SIG_STatt      -0.150180
# age                    -0.122322
# avg_SIG_STatt          -0.122117
# avg_opp_TOTAL_STatt    -0.102073
# avg_SIG_STlanded       -0.100251
# avg_TOTAL_STatt        -0.080250
# avg_opp_SUATT          -0.079451
# avg_SUATT              -0.061465
# avg_opp_TD_pct         -0.061202
# Name: won, dtype: float64

# %%
# Print all non-numeric columns — often includes categories like stance
print("Categorical columns:")
print(df_fighter_stats.select_dtypes(include='object').columns.to_list())

# Print all numeric columns
print("\nNumeric columns:")
print(df_fighter_stats.select_dtypes(include='number').columns.to_list())
# Out:
# Categorical columns:
# ['fighter', 'Stance', 'fighter_name', 'weight_class']
#
# Numeric columns:
# ['avg_KD', 'avg_opp_KD', 'avg_SIG_STpct', 'avg_opp_SIG_STpct', 'avg_TD_pct', 'avg_opp_TD_pct', 'avg_SUB_ATT', 'avg_opp_SUB_ATT', 'avg_REV', 'avg_opp_REV', 'avg_SIG_STatt', 'avg_SIG_STlanded', 'avg_opp_SIG_STatt', 'avg_opp_SIG_STlanded', 'avg_TOTAL_STatt', 'avg_TOTAL_STlanded', 'avg_opp_TOTAL_STatt', 'avg_opp_TOTAL_STlanded', 'avg_TD_att', 'avg_TD_landed', 'avg_opp_TD_att', 'avg_opp_TD_landed', 'avg_HEAD_att', 'avg_HEAD_landed', 'avg_opp_HEAD_att', 'avg_opp_HEAD_landed', 'avg_BODY_att', 'avg_BODY_landed', 'avg_opp_BODY_att', 'avg_opp_BODY_landed', 'avg_LEG_att', 'avg_LEG_landed', 'avg_opp_LEG_att', 'avg_opp_LEG_landed', 'avg_DISTANCE_att', 'avg_DISTANCE_landed', 'avg_opp_DISTANCE_att', 'avg_opp_DISTANCE_landed', 'avg_CLINCH_att', 'avg_CLINCH_landed', 'avg_opp_CLINCH_att', 'avg_opp_CLINCH_landed', 'avg_GROUND_att', 'avg_GROUND_landed', 'avg_opp_GROUND_att', 'avg_opp_GROUND_landed', 'avg_CTRL_time(seconds)', 'avg_opp_CTRL_time(seconds)', 'total_time_fought(seconds)', 'total_rounds_fought', 'total_title_bouts', 'current_win_streak', 'current_lose_streak', 'longest_win_streak', 'wins', 'losses', 'draw', 'win_by_Decision_Majority', 'win_by_Decision_Split', 'win_by_Decision_Unanimous', 'win_by_KO/TKO', 'win_by_Submission', 'win_by_TKO_Doctor_Stoppage', 'Height_cms', 'Reach_cms', 'Weight_lbs', 'age', 'avg_SIG_STR_pct', 'avg_opp_SIG_STR_pct', 'avg_SUATT', 'avg_opp_SUATT', 'avg_SIG_STR_att', 'avg_SIG_STR_landed', 'avg_opp_SIG_STR_att', 'avg_opp_SIG_STR_landed', 'avg_TOTAL_STR_att', 'avg_TOTAL_STR_landed', 'avg_opp_TOTAL_STR_att', 'avg_opp_TOTAL_STR_landed']

# %%
trait_cols = [
    'age', 'Height_cms', 'Reach_cms', 'Weight_lbs',
    'wins', 'losses', 'draw',
    'current_win_streak', 'current_lose_streak', 'longest_win_streak',
    'total_time_fought(seconds)', 'total_rounds_fought', 'total_title_bouts'
]

# Correlation with win outcome
trait_corr = df_fighter_stats[trait_cols + ['won']].corr()['won'].sort_values(ascending=False)
print(trait_corr)
# Out:
# won                           1.000000
# longest_win_streak            0.063093
# current_win_streak            0.061280
# total_time_fought(seconds)    0.034891
# wins                          0.031536
# Reach_cms                     0.031536
# total_title_bouts             0.029751
# Height_cms                    0.016732
# total_rounds_fought           0.015168
# Weight_lbs                    0.002765
# losses                       -0.020919
# current_lose_streak          -0.032674
# age                          -0.090976
# draw                               NaN
# Name: won, dtype: float64

# %%
# Filter to fights that had a clear winner
df_fights = df[df['Winner'].isin(['Red', 'Blue'])].copy()

# Add a binary outcome column: 1 if Red won, 0 if Blue won
df_fights['R_winner'] = df_fights['Winner'].apply(lambda x: 1 if x == 'Red' else 0)

# %%
# Create difference columns (Red - Blue)
df_fights['age_diff'] = df_fights['R_age'] - df_fights['B_age']
df_fights['height_diff'] = df_fights['R_Height_cms'] - df_fights['B_Height_cms']
df_fights['reach_diff'] = df_fights['R_Reach_cms'] - df_fights['B_Reach_cms']
df_fights['win_streak_diff'] = df_fights['R_current_win_streak'] - df_fights['B_current_win_streak']

# %%
# Select just the differential columns and the outcome
diff_cols = ['age_diff', 'height_diff', 'reach_diff', 'win_streak_diff', 'R_winner']

# Calculate correlation with R_winner
df_fights[diff_cols].corr()['R_winner'].sort_values(ascending=False)
# Out:
# R_winner           1.000000
# reach_diff         0.066734
# height_diff        0.044093
# win_streak_diff    0.037662
# age_diff          -0.170361
# Name: R_winner, dtype: float64

# %%
# View average win rate by fighter stance
stance_winrate = df_fighter_stats.groupby('Stance')['won'].mean().sort_values(ascending=False)
print(stance_winrate)
# Out:
# Stance
# Open Stance    0.541667
# Southpaw       0.527660
# Switch         0.523256
# Orthodox       0.494946
# Sideways       0.333333
# Name: won, dtype: float64

# %%
df_fighter_stats['Stance'].value_counts()
# Out:
# Stance
# Orthodox       8904
# Southpaw       2350
# Switch          430
# Open Stance      24
# Sideways          6
# Name: count, dtype: int64

# %%
# Count of each stance
stance_counts = df_fighter_stats['Stance'].value_counts()

# Win rate of each stance
stance_winrate = df_fighter_stats.groupby('Stance')['won'].mean()

# Combine into one DataFrame
stance_summary = pd.DataFrame({
    'Win Rate': stance_winrate,
    'Count': stance_counts
}).sort_values(by='Win Rate', ascending=False)

print(stance_summary)
# Out:
#              Win Rate  Count
# Stance
# Open Stance  0.541667     24
# Southpaw     0.527660   2350
# Switch       0.523256    430
# Orthodox     0.494946   8904
# Sideways     0.333333      6

# %%
df_fighter_stats['weight_class'].value_counts()
# Out:
# weight_class
# Lightweight           2144
# Welterweight          2132
# Middleweight          1606
# Heavyweight           1146
# LightHeavyweight      1118
# Featherweight         1078
# Bantamweight           924
# Flyweight              452
# WomenStrawweight       380
# WomenBantamweight      298
# WomenFlyweight         220
# OpenWeight             172
# CatchWeight            102
# WomenFeatherweight      32
# Name: count, dtype: int64

# %%
weight_class
Lightweight           2144
Welterweight          2132
Middleweight          1606
Heavyweight           1146
LightHeavyweight      1118
Featherweight         1078
Bantamweight           924
Flyweight              452
WomenStrawweight       380
WomenBantamweight      298
WomenFlyweight         220
OpenWeight             172
CatchWeight            102
WomenFeatherweight      32
# Out:
#   Cell In[29], line 2
#     Lightweight           2144
#                           ^
# SyntaxError: invalid syntax

# %%
def correlate_by_weight_class(df, numeric_cols, target_col='won'):
    results = {}

    for wc in df['weight_class'].unique():
        subset = df[df['weight_class'] == wc]

        # Avoid tiny groups
        if len(subset) < 100:
            continue

        # Only include numeric columns that exist in this subset
        numeric_subset = subset[numeric_cols].select_dtypes(include='number')

        # Drop any NaNs
        corr = numeric_subset.corr()[target_col].dropna()

        # Save top and bottom 10
        results[wc] = {
            'Top 10': corr.sort_values(ascending=False).head(10),
            'Bottom 10': corr.sort_values().head(10)
        }

    return results

# Run the function
correlations_by_weight_class = correlate_by_weight_class(df_fighter_stats, df_fighter_stats.select_dtypes(include='number').columns)

# Example: print Lightweight
print("🔷 Top 10 for Lightweight:")
print(correlations_by_weight_class['Lightweight']['Top 10'])
print("\n🔻 Bottom 10 for Lightweight:")
print(correlations_by_weight_class['Lightweight']['Bottom 10'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'won'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 26
#      23     return results
#      25 # Run the function
# ---> 26 correlations_by_weight_class = correlate_by_weight_class(df_fighter_stats, df_fighter_stats.select_dtypes(include='number').columns)
#      28 # Example: print Lightweight
#      29 print("🔷 Top 10 for Lightweight:")
#
# Cell In[30], line 15, in correlate_by_weight_class(df, numeric_cols, target_col)
#      12 numeric_subset = subset[numeric_cols].select_dtypes(include='number')
#      14 # Drop any NaNs
# ---> 15 corr = numeric_subset.corr()[target_col].dropna()
#      17 # Save top and bottom 10
#      18 results[wc] = {
#      19     'Top 10': corr.sort_values(ascending=False).head(10),
#      20     'Bottom 10': corr.sort_values().head(10)
#      21 }
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'won'

# %%
non_combat_cols = [
    'age',
    'Height_cms',
    'Reach_cms',
    'Weight_lbs',
    'wins',
    'losses',
    'draw',
    'current_win_streak',
    'current_lose_streak',
    'longest_win_streak',
    'total_rounds_fought',
    'total_time_fought(seconds)',
    'total_title_bouts'
]

# %%
def correlate_noncombat_by_weight_class(df, cols, target='won'):
    results = {}

    for wc in df['weight_class'].unique():
        subset = df[df['weight_class'] == wc]

        if len(subset) < 100:
            continue

        numeric_subset = subset[cols].copy()
        numeric_subset[target] = subset[target]

        corr = numeric_subset.corr()[target].dropna()
        results[wc] = corr.sort_values(ascending=False)

    return results

noncombat_corr_by_wc = correlate_noncombat_by_weight_class(df_fighter_stats, non_combat_cols)

# %%
print("🔷 Lightweight Non-Combat Correlations:")
print(noncombat_corr_by_wc['Lightweight'])
# Out:
# 🔷 Lightweight Non-Combat Correlations:
# won                           1.000000
# current_win_streak            0.088703
# longest_win_streak            0.067346
# wins                          0.043337
# total_time_fought(seconds)    0.033381
# Reach_cms                     0.020164
# Weight_lbs                    0.018217
# total_rounds_fought           0.016973
# Height_cms                   -0.003102
# total_title_bouts            -0.007595
# losses                       -0.010792
# current_lose_streak          -0.042939
# age                          -0.122322
# Name: won, dtype: float64

# %%
# Define columns for differential analysis
df_fighter_stats['reach_diff'] = df_fighter_stats['Reach_cms'] - df_fighter_stats['Reach_cms'].mean()
df_fighter_stats['height_diff'] = df_fighter_stats['Height_cms'] - df_fighter_stats['Height_cms'].mean()
df_fighter_stats['win_streak_diff'] = df_fighter_stats['current_win_streak'] - df_fighter_stats['current_win_streak'].mean()
df_fighter_stats['age_diff'] = df_fighter_stats['age'] - df_fighter_stats['age'].mean()

diff_cols = ['reach_diff', 'height_diff', 'win_streak_diff', 'age_diff']

# %%
def get_all_correlations_by_weight(df, target_col='won'):
    weight_classes = df['weight_class'].dropna().unique()
    
    # Define non-combat columns
    noncombat_cols = [
        'age', 'Height_cms', 'Reach_cms', 'Weight_lbs',
        'wins', 'losses', 'draw',
        'current_win_streak', 'current_lose_streak',
        'longest_win_streak', 'total_rounds_fought',
        'total_time_fought(seconds)', 'total_title_bouts'
    ]
    
    # Define differential columns
    diff_cols = ['reach_diff', 'height_diff', 'win_streak_diff', 'age_diff']
    
    results = {}

    for wc in weight_classes:
        subset = df[df['weight_class'] == wc]

        if len(subset) < 100:
            continue

        result = {}

        # Overall top/bottom 10 numeric correlations
        num_cols = subset.select_dtypes(include='number').columns
        corr_all = subset[num_cols].corr()[target_col].dropna()
        result['Top 10 Overall'] = corr_all.sort_values(ascending=False).head(10)
        result['Bottom 10 Overall'] = corr_all.sort_values().head(10)

        # Non-combat only
        corr_noncombat = subset[noncombat_cols + [target_col]].corr()[target_col].dropna()
        result['Non-Combat'] = corr_noncombat.sort_values(ascending=False)

        # Differential only
        corr_diff = subset[diff_cols + [target_col]].corr()[target_col].dropna()
        result['Differentials'] = corr_diff.sort_values(ascending=False)

        results[wc] = result

    return results

# Run the master function
full_corr_by_weight = get_all_correlations_by_weight(df_fighter_stats)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'won'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 45
#      42     return results
#      44 # Run the master function
# ---> 45 full_corr_by_weight = get_all_correlations_by_weight(df_fighter_stats)
#
# Cell In[35], line 28, in get_all_correlations_by_weight(df, target_col)
#      26 # Overall top/bottom 10 numeric correlations
#      27 num_cols = subset.select_dtypes(include='number').columns
# ---> 28 corr_all = subset[num_cols].corr()[target_col].dropna()
#      29 result['Top 10 Overall'] = corr_all.sort_values(ascending=False).head(10)
#      30 result['Bottom 10 Overall'] = corr_all.sort_values().head(10)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'won'

# %%
# Make sure the 'won' column exists
df_fighter_stats['won'] = df_fighter_stats['R_winner']  # or whichever column you've been using
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'R_winner'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 2
#       1 # Make sure the 'won' column exists
# ----> 2 df_fighter_stats['won'] = df_fighter_stats['R_winner']  # or whichever column you've been using
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'R_winner'

# %%
print(df_fighter_stats.columns.to_list())
# Out:
# ['fighter', 'avg_KD', 'avg_opp_KD', 'avg_SIG_STpct', 'avg_opp_SIG_STpct', 'avg_TD_pct', 'avg_opp_TD_pct', 'avg_SUB_ATT', 'avg_opp_SUB_ATT', 'avg_REV', 'avg_opp_REV', 'avg_SIG_STatt', 'avg_SIG_STlanded', 'avg_opp_SIG_STatt', 'avg_opp_SIG_STlanded', 'avg_TOTAL_STatt', 'avg_TOTAL_STlanded', 'avg_opp_TOTAL_STatt', 'avg_opp_TOTAL_STlanded', 'avg_TD_att', 'avg_TD_landed', 'avg_opp_TD_att', 'avg_opp_TD_landed', 'avg_HEAD_att', 'avg_HEAD_landed', 'avg_opp_HEAD_att', 'avg_opp_HEAD_landed', 'avg_BODY_att', 'avg_BODY_landed', 'avg_opp_BODY_att', 'avg_opp_BODY_landed', 'avg_LEG_att', 'avg_LEG_landed', 'avg_opp_LEG_att', 'avg_opp_LEG_landed', 'avg_DISTANCE_att', 'avg_DISTANCE_landed', 'avg_opp_DISTANCE_att', 'avg_opp_DISTANCE_landed', 'avg_CLINCH_att', 'avg_CLINCH_landed', 'avg_opp_CLINCH_att', 'avg_opp_CLINCH_landed', 'avg_GROUND_att', 'avg_GROUND_landed', 'avg_opp_GROUND_att', 'avg_opp_GROUND_landed', 'avg_CTRL_time(seconds)', 'avg_opp_CTRL_time(seconds)', 'total_time_fought(seconds)', 'total_rounds_fought', 'total_title_bouts', 'current_win_streak', 'current_lose_streak', 'longest_win_streak', 'wins', 'losses', 'draw', 'win_by_Decision_Majority', 'win_by_Decision_Split', 'win_by_Decision_Unanimous', 'win_by_KO/TKO', 'win_by_Submission', 'win_by_TKO_Doctor_Stoppage', 'Stance', 'Height_cms', 'Reach_cms', 'Weight_lbs', 'age', 'won', 'fighter_name', 'weight_class', 'avg_SIG_STR_pct', 'avg_opp_SIG_STR_pct', 'avg_SUATT', 'avg_opp_SUATT', 'avg_SIG_STR_att', 'avg_SIG_STR_landed', 'avg_opp_SIG_STR_att', 'avg_opp_SIG_STR_landed', 'avg_TOTAL_STR_att', 'avg_TOTAL_STR_landed', 'avg_opp_TOTAL_STR_att', 'avg_opp_TOTAL_STR_landed', 'reach_diff', 'height_diff', 'win_streak_diff', 'age_diff']

# %%
def get_all_correlations_by_weight(df, target_col='won'):
    results = {}

    # Define non-combat and differential columns
    non_combat_cols = [
        'current_win_streak', 'longest_win_streak', 'wins', 'losses', 'draw',
        'total_time_fought(seconds)', 'total_rounds_fought', 'total_title_bouts',
        'Height_cms', 'Reach_cms', 'Weight_lbs', 'age'
    ]
    diff_cols = ['reach_diff', 'height_diff', 'win_streak_diff', 'age_diff']

    for weight_class in df['weight_class'].unique():
        result = {}
        subset = df[df['weight_class'] == weight_class]

        # Overall top/bottom 10 numeric correlations
        num_cols = subset.select_dtypes(include='number').columns
        corr_all = subset[num_cols].corr()[target_col].dropna()
        result['Top 10 Overall'] = corr_all.sort_values(ascending=False).head(10)
        result['Bottom 10 Overall'] = corr_all.sort_values().head(10)

        # Non-combat correlations
        non_combat_existing = [col for col in non_combat_cols if col in subset.columns]
        if non_combat_existing:
            result['Non-Combat'] = subset[non_combat_existing + [target_col]].corr()[target_col].drop(target_col)

        # Differential correlations
        diff_existing = [col for col in diff_cols if col in subset.columns]
        if diff_existing:
            result['Differentials'] = subset[diff_existing + [target_col]].corr()[target_col].drop(target_col)

        results[weight_class] = result

    return results

# Run it!
full_corr_by_weight = get_all_correlations_by_weight(df_fighter_stats)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'won'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 37
#      34     return results
#      36 # Run it!
# ---> 37 full_corr_by_weight = get_all_correlations_by_weight(df_fighter_stats)
#
# Cell In[38], line 18, in get_all_correlations_by_weight(df, target_col)
#      16 # Overall top/bottom 10 numeric correlations
#      17 num_cols = subset.select_dtypes(include='number').columns
# ---> 18 corr_all = subset[num_cols].corr()[target_col].dropna()
#      19 result['Top 10 Overall'] = corr_all.sort_values(ascending=False).head(10)
#      20 result['Bottom 10 Overall'] = corr_all.sort_values().head(10)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'won'

# %%
print('won' in df_fighter_stats.columns)
# Out:
# True

# %%
def get_all_correlations_by_weight(df, target_col='won'):
    results = {}

    # Define non-combat and differential columns
    non_combat_cols = [
        'current_win_streak', 'longest_win_streak', 'wins', 'losses', 'draw',
        'total_time_fought(seconds)', 'total_rounds_fought', 'total_title_bouts',
        'Height_cms', 'Reach_cms', 'Weight_lbs', 'age'
    ]
    diff_cols = ['reach_diff', 'height_diff', 'win_streak_diff', 'age_diff']

    for weight_class in df['weight_class'].dropna().unique():
        subset = df[df['weight_class'] == weight_class]

        # ✅ Skip if target column missing
        if target_col not in subset.columns:
            print(f"Skipping {weight_class}: '{target_col}' column missing")
            continue

        result = {}

        # Top/bottom 10 numeric correlations
        num_cols = subset.select_dtypes(include='number').columns
        if target_col not in num_cols:
            continue  # skip if 'won' is not numeric

        corr_all = subset[num_cols].corr()[target_col].dropna()
        result['Top 10 Overall'] = corr_all.sort_values(ascending=False).head(10)
        result['Bottom 10 Overall'] = corr_all.sort_values().head(10)

        # Non-combat correlations
        non_combat_existing = [col for col in non_combat_cols if col in subset.columns]
        if non_combat_existing:
            result['Non-Combat'] = subset[non_combat_existing + [target_col]].corr()[target_col].drop(target_col)

        # Differential correlations
        diff_existing = [col for col in diff_cols if col in subset.columns]
        if diff_existing:
            result['Differentials'] = subset[diff_existing + [target_col]].corr()[target_col].drop(target_col)

        results[weight_class] = result

    return results

# %%
full_corr_by_weight = get_all_correlations_by_weight(df_fighter_stats)

# %%
from pprint import pprint
pprint(full_corr_by_weight['Lightweight'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 2
#       1 from pprint import pprint
# ----> 2 pprint(full_corr_by_weight['Lightweight'])
#
# KeyError: 'Lightweight'

# %%
print(list(full_corr_by_weight.keys()))
# Out:
# []

# %%
print(df_fighter_stats.columns.tolist())
# Out:
# ['fighter', 'avg_KD', 'avg_opp_KD', 'avg_SIG_STpct', 'avg_opp_SIG_STpct', 'avg_TD_pct', 'avg_opp_TD_pct', 'avg_SUB_ATT', 'avg_opp_SUB_ATT', 'avg_REV', 'avg_opp_REV', 'avg_SIG_STatt', 'avg_SIG_STlanded', 'avg_opp_SIG_STatt', 'avg_opp_SIG_STlanded', 'avg_TOTAL_STatt', 'avg_TOTAL_STlanded', 'avg_opp_TOTAL_STatt', 'avg_opp_TOTAL_STlanded', 'avg_TD_att', 'avg_TD_landed', 'avg_opp_TD_att', 'avg_opp_TD_landed', 'avg_HEAD_att', 'avg_HEAD_landed', 'avg_opp_HEAD_att', 'avg_opp_HEAD_landed', 'avg_BODY_att', 'avg_BODY_landed', 'avg_opp_BODY_att', 'avg_opp_BODY_landed', 'avg_LEG_att', 'avg_LEG_landed', 'avg_opp_LEG_att', 'avg_opp_LEG_landed', 'avg_DISTANCE_att', 'avg_DISTANCE_landed', 'avg_opp_DISTANCE_att', 'avg_opp_DISTANCE_landed', 'avg_CLINCH_att', 'avg_CLINCH_landed', 'avg_opp_CLINCH_att', 'avg_opp_CLINCH_landed', 'avg_GROUND_att', 'avg_GROUND_landed', 'avg_opp_GROUND_att', 'avg_opp_GROUND_landed', 'avg_CTRL_time(seconds)', 'avg_opp_CTRL_time(seconds)', 'total_time_fought(seconds)', 'total_rounds_fought', 'total_title_bouts', 'current_win_streak', 'current_lose_streak', 'longest_win_streak', 'wins', 'losses', 'draw', 'win_by_Decision_Majority', 'win_by_Decision_Split', 'win_by_Decision_Unanimous', 'win_by_KO/TKO', 'win_by_Submission', 'win_by_TKO_Doctor_Stoppage', 'Stance', 'Height_cms', 'Reach_cms', 'Weight_lbs', 'age', 'won', 'fighter_name', 'weight_class', 'avg_SIG_STR_pct', 'avg_opp_SIG_STR_pct', 'avg_SUATT', 'avg_opp_SUATT', 'avg_SIG_STR_att', 'avg_SIG_STR_landed', 'avg_opp_SIG_STR_att', 'avg_opp_SIG_STR_landed', 'avg_TOTAL_STR_att', 'avg_TOTAL_STR_landed', 'avg_opp_TOTAL_STR_att', 'avg_opp_TOTAL_STR_landed', 'reach_diff', 'height_diff', 'win_streak_diff', 'age_diff']

# %%
print(df_fighter_stats['weight_class'].dropna().unique())
# Out:
# ['Bantamweight' 'Middleweight' 'Heavyweight' 'WomenStrawweight'
#  'WomenBantamweight' 'Lightweight' 'Welterweight' 'Flyweight'
#  'LightHeavyweight' 'Featherweight' 'WomenFlyweight' 'WomenFeatherweight'
#  'CatchWeight' 'OpenWeight']

# %%
def get_all_correlations_by_weight(df, target_col='won'):
    results = {}
    
    weight_classes = df['weight_class'].dropna().unique()
    
    # Define column groups
    non_combat_cols = [
        'current_win_streak', 'current_lose_streak', 'longest_win_streak',
        'wins', 'losses', 'draw', 'total_time_fought(seconds)',
        'total_rounds_fought', 'total_title_bouts', 'Reach_cms', 'Height_cms',
        'Weight_lbs', 'age'
    ]
    
    differential_cols = ['reach_diff', 'height_diff', 'win_streak_diff', 'age_diff']
    
    for wc in weight_classes:
        subset = df[df['weight_class'] == wc].copy()
        
        # Skip if not enough data
        if subset.shape[0] < 30:
            continue
        
        result = {}

        # Overall correlations
        num_cols = subset.select_dtypes(include='number').columns
        if target_col not in num_cols:
            continue
        
        corr_all = subset[num_cols].corr()[target_col].dropna()
        result['Top 10 Overall'] = corr_all.abs().sort_values(ascending=False).head(10)
        result['Bottom 10 Overall'] = corr_all.abs().sort_values().head(10)

        # Non-combat correlations
        non_combat_present = [col for col in non_combat_cols if col in subset.columns]
        if non_combat_present:
            result['Non-Combat'] = subset[non_combat_present + [target_col]].corr()[target_col].dropna()

        # Differential correlations
        diff_present = [col for col in differential_cols if col in subset.columns]
        if diff_present:
            result['Differentials'] = subset[diff_present + [target_col]].corr()[target_col].dropna()

        results[wc] = result

    return results

# %%
full_corr_by_weight = get_all_correlations_by_weight(df_fighter_stats)

# %%
from pprint import pprint
pprint(full_corr_by_weight['Lightweight'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 2
#       1 from pprint import pprint
# ----> 2 pprint(full_corr_by_weight['Lightweight'])
#
# KeyError: 'Lightweight'

# %%
print(full_corr_by_weight.keys())
# Out:
# dict_keys([])

# %%
df_fighter_stats['weight_class'].value_counts()
# Out:
# weight_class
# Lightweight           2144
# Welterweight          2132
# Middleweight          1606
# Heavyweight           1146
# LightHeavyweight      1118
# Featherweight         1078
# Bantamweight           924
# Flyweight              452
# WomenStrawweight       380
# WomenBantamweight      298
# WomenFlyweight         220
# OpenWeight             172
# CatchWeight            102
# WomenFeatherweight      32
# Name: count, dtype: int64

# %%
df_fighter_stats[df_fighter_stats['weight_class'] == 'Lightweight']['won'].describe()
# Out:
# count      2144
# unique        2
# top       False
# freq       1072
# Name: won, dtype: object

# %%
# Convert won column from boolean to integer
df_fighter_stats['won'] = df_fighter_stats['won'].astype(int)

# %%
full_corr_by_weight = get_all_correlations_by_weight(df_fighter_stats)

# %%
from pprint import pprint
pprint(full_corr_by_weight['Lightweight'])
# Out:
# {'Bottom 10 Overall': avg_DISTANCE_landed         0.001067
# Height_cms                  0.003102
# height_diff                 0.003102
# avg_BODY_landed             0.003263
# avg_DISTANCE_att            0.004240
# avg_BODY_att                0.005419
# win_by_Decision_Majority    0.006731
# total_title_bouts           0.007595
# avg_CLINCH_att              0.007640
# avg_REV                     0.008448
# Name: won, dtype: float64,
#  'Differentials': reach_diff         0.020164
# height_diff       -0.003102
# win_streak_diff    0.088703
# age_diff          -0.122322
# won                1.000000
# Name: won, dtype: float64,
#  'Non-Combat': current_win_streak            0.088703
# current_lose_streak          -0.042939
# longest_win_streak            0.067346
# wins                          0.043337
# losses                       -0.010792
# total_time_fought(seconds)    0.033381
# total_rounds_fought           0.016973
# total_title_bouts            -0.007595
# Reach_cms                     0.020164
# Height_cms                   -0.003102
# Weight_lbs                    0.018217
# age                          -0.122322
# won                           1.000000
# Name: won, dtype: float64,
#  'Top 10 Overall': won                     1.000000
# avg_opp_SIG_STlanded    0.163795
# avg_SUB_ATT             0.157656
# avg_SIG_STR_landed      0.156207
# avg_SIG_STR_att         0.152992
# avg_opp_SIG_STatt       0.150180
# avg_opp_SUB_ATT         0.136987
# age_diff                0.122322
# age                     0.122322
# avg_SIG_STatt           0.122117
# Name: won, dtype: float64}

# %%
# Step 1: Filter only fights with a clear winner
df_fights = df[df['Winner'].isin(['Red', 'Blue'])].copy()

# Step 2: Create red fighter DataFrame
red = df_fights[[col for col in df_fights.columns if col.startswith('R_')]].copy()
red.columns = [col.replace('R_', '') for col in red.columns]
red['won'] = (df_fights['Winner'] == 'Red').astype(int)
red['fighter_name'] = df_fights['R_fighter']
red['weight_class'] = df_fights['weight_class']
red['Stance'] = df_fights['R_Stance']
red['age'] = df_fights['R_age']
red['Height_cms'] = df_fights['R_Height_cms']
red['Reach_cms'] = df_fights['R_Reach_cms']
red['Weight_lbs'] = df_fights['R_Weight_lbs']

# Step 3: Create blue fighter DataFrame
blue = df_fights[[col for col in df_fights.columns if col.startswith('B_')]].copy()
blue.columns = [col.replace('B_', '') for col in blue.columns]
blue['won'] = (df_fights['Winner'] == 'Blue').astype(int)
blue['fighter_name'] = df_fights['B_fighter']
blue['weight_class'] = df_fights['weight_class']
blue['Stance'] = df_fights['B_Stance']
blue['age'] = df_fights['B_age']
blue['Height_cms'] = df_fights['B_Height_cms']
blue['Reach_cms'] = df_fights['B_Reach_cms']
blue['Weight_lbs'] = df_fights['B_Weight_lbs']

# Step 4: Combine red and blue into one fighter-level dataset
df_fighter_stats = pd.concat([red, blue], ignore_index=True)

# %%
df_fighter_stats.head()
# Out:
#          fighter    avg_KD  avg_opp_KD  avg_SIG_STpct  avg_opp_SIG_STpct  \
# 0   Adrian Yanez  1.000000    0.000000       0.500000           0.460000
# 1   Trevin Giles  1.031250    0.062500       0.576875           0.381250
# 2    Tai Tuivasa  0.546875    0.187500       0.538906           0.598594
# 3  Cheyanne Buys       NaN         NaN            NaN                NaN
# 4  Marion Reneau  0.000000    0.000977       0.403076           0.554961
#
#    avg_TD_pct  avg_opp_TD_pct  avg_SUB_ATT  avg_opp_SUB_ATT  avg_REV  ...  \
# 0    0.000000         0.00000     0.000000          0.00000  0.00000  ...
# 1    0.406250         0.11625     0.250000          1.18750  0.37500  ...
# 2    0.000000         0.31250     0.000000          0.25000  0.00000  ...
# 3         NaN             NaN          NaN              NaN      NaN  ...
# 4    0.511719         0.62875     0.231445          0.03125  0.03125  ...
#
#    avg_SUATT  avg_opp_SUATT  avg_SIG_STR_att  avg_SIG_STR_landed  \
# 0        NaN            NaN              NaN                 NaN
# 1        NaN            NaN              NaN                 NaN
# 2        NaN            NaN              NaN                 NaN
# 3        NaN            NaN              NaN                 NaN
# 4        NaN            NaN              NaN                 NaN
#
#    avg_opp_SIG_STR_att  avg_opp_SIG_STR_landed  avg_TOTAL_STR_att  \
# 0                  NaN                     NaN                NaN
# 1                  NaN                     NaN                NaN
# 2                  NaN                     NaN                NaN
# 3                  NaN                     NaN                NaN
# 4                  NaN                     NaN                NaN
#
#    avg_TOTAL_STR_landed  avg_opp_TOTAL_STR_att  avg_opp_TOTAL_STR_landed
# 0                   NaN                    NaN                       NaN
# 1                   NaN                    NaN                       NaN
# 2                   NaN                    NaN                       NaN
# 3                   NaN                    NaN                       NaN
# 4                   NaN                    NaN                       NaN
#
# [5 rows x 84 columns]

# %%
# Step 1: Define groups of column names
non_combat_cols = [
    'current_win_streak', 'current_lose_streak', 'longest_win_streak', 'wins', 'losses', 'draw',
    'total_time_fought(seconds)', 'total_rounds_fought', 'total_title_bouts',
    'Reach_cms', 'Height_cms', 'Weight_lbs', 'age'
]

diff_cols = ['reach_diff', 'height_diff', 'win_streak_diff', 'age_diff']
target_col = 'won'

# %%
def get_cleaned_correlations_by_weight(df):
    results = {}
    weight_classes = df['weight_class'].dropna().unique()

    for wc in weight_classes:
        subset = df[df['weight_class'] == wc]

        # Skip if not enough data
        if subset[target_col].nunique() < 2 or len(subset) < 50:
            continue

        # --- Overall Top & Bottom 10 Correlations (absolute, excluding 'won' itself)
        numeric_cols = subset.select_dtypes(include='number').columns.drop(target_col)
        corr_series = subset[numeric_cols].corrwith(subset[target_col]).dropna()
        top10 = corr_series.abs().sort_values(ascending=False).head(10)
        bottom10 = corr_series.abs().sort_values(ascending=True).head(10)

        # --- Non-Combat Correlations (sorted by actual correlation, not abs)
        non_combat_clean = [
            col for col in non_combat_cols if col in subset.columns
        ]
        nc_corrs = subset[non_combat_clean + [target_col]].corr()[target_col].drop(target_col)
        nc_corrs = nc_corrs.sort_values(ascending=False)

        # --- Differential Correlations
        diff_clean = [col for col in diff_cols if col in subset.columns]
        diff_corrs = subset[diff_clean + [target_col]].corr()[target_col].drop(target_col)
        diff_corrs = diff_corrs.sort_values(ascending=False)

        # --- Stance win rates
        if 'Stance' in subset.columns:
            stance_win_rates = subset.groupby('Stance')[target_col].mean().sort_values(ascending=False)
            stance_counts = subset['Stance'].value_counts()
            stance_data = pd.DataFrame({
                'win_rate': stance_win_rates,
                'count': stance_counts
            }).dropna()
        else:
            stance_data = pd.DataFrame()

        results[wc] = {
            'Top 10 Absolute Correlations': corr_series[top10.index],
            'Bottom 10 Absolute Correlations': corr_series[bottom10.index],
            'Non-Combat Correlations': nc_corrs,
            'Differential Correlations': diff_corrs,
            'Stance Win Rates': stance_data
        }

    return results

# %%
# Run the function and store output
correlation_summary_by_weight = get_cleaned_correlations_by_weight(df_fighter_stats)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/codespace/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
from pprint import pprint
pprint(correlation_summary_by_weight['Lightweight'])
# Out:
# {'Bottom 10 Absolute Correlations': avg_DISTANCE_landed        -0.001067
# Height_cms                 -0.003102
# avg_BODY_landed             0.003263
# avg_DISTANCE_att           -0.004240
# avg_BODY_att               -0.005419
# win_by_Decision_Majority   -0.006731
# total_title_bouts          -0.007595
# avg_CLINCH_att             -0.007640
# avg_REV                    -0.008448
# avg_opp_DISTANCE_att       -0.009125
# dtype: float64,
#  'Differential Correlations': Series([], Name: won, dtype: float64),
#  'Non-Combat Correlations': current_win_streak            0.088703
# longest_win_streak            0.067346
# wins                          0.043337
# total_time_fought(seconds)    0.033381
# Reach_cms                     0.020164
# Weight_lbs                    0.018217
# total_rounds_fought           0.016973
# Height_cms                   -0.003102
# total_title_bouts            -0.007595
# losses                       -0.010792
# current_lose_streak          -0.042939
# age                          -0.122322
# draw                               NaN
# Name: won, dtype: float64,
#  'Stance Win Rates':           win_rate  count
# Stance
# Orthodox  0.492598   1486
# Southpaw  0.539792    578
# Switch    0.435484     62,
#  'Top 10 Absolute Correlations': avg_opp_SIG_STlanded   -0.163795
# avg_SUB_ATT             0.157656
# avg_SIG_STR_landed      0.156207
# avg_SIG_STR_att         0.152992
# avg_opp_SIG_STatt      -0.150180
# avg_opp_SUB_ATT         0.136987
# age                    -0.122322
# avg_SIG_STatt          -0.122117
# avg_TOTAL_STR_att       0.106301
# avg_GROUND_att          0.104920
# dtype: float64}

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set(style='whitegrid')
plt.figure(figsize=(16, 12))

# 1. Top 10 Absolute Correlations
plt.subplot(2, 2, 1)
top_corr = lightweight_corrs['Top 10 Absolute Correlations']
sns.barplot(x=top_corr.values, y=top_corr.index, palette='viridis')
plt.title('Top 10 Absolute Correlations with Victory')

# 2. Bottom 10 Absolute Correlations
plt.subplot(2, 2, 2)
bottom_corr = lightweight_corrs['Bottom 10 Absolute Correlations']
sns.barplot(x=bottom_corr.values, y=bottom_corr.index, palette='mako')
plt.title('Bottom 10 Absolute Correlations with Victory')

# 3. Non-Combat Stat Correlations
plt.subplot(2, 2, 3)
non_combat = lightweight_corrs['Non-Combat Correlations'].dropna().sort_values()
sns.barplot(x=non_combat.values, y=non_combat.index, palette='coolwarm')
plt.title('Non-Combat Stat Correlations with Victory')

# 4. Stance Win Rates
plt.subplot(2, 2, 4)
stance = lightweight_corrs['Stance Win Rates']
sns.barplot(x=stance['win_rate'], y=stance.index, palette='Set2')
plt.title('Win Rates by Stance (Lightweight)')

# Final layout tweaks
plt.tight_layout()
plt.savefig("lightweight_dashboard.png", dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 10
#       8 # 1. Top 10 Absolute Correlations
#       9 plt.subplot(2, 2, 1)
# ---> 10 top_corr = lightweight_corrs['Top 10 Absolute Correlations']
#      11 sns.barplot(x=top_corr.values, y=top_corr.index, palette='viridis')
#      12 plt.title('Top 10 Absolute Correlations with Victory')
#
# NameError: name 'lightweight_corrs' is not defined

# %%
lightweight_corrs = get_cleaned_correlation_summary_by_class(df_fighter_stats, 'Lightweight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 lightweight_corrs = get_cleaned_correlation_summary_by_class(df_fighter_stats, 'Lightweight')
#
# NameError: name 'get_cleaned_correlation_summary_by_class' is not defined

# %%
def get_cleaned_correlation_summary_by_class(df, weight_class):
    """
    Returns a cleaned summary of correlation results for a specific weight class.
    Includes:
    - Top 10 Absolute Correlations
    - Bottom 10 Absolute Correlations
    - Non-Combat Stat Correlations
    - Differential Correlations
    - Stance Win Rates
    """
    subset = df[df['weight_class'] == weight_class].copy()

    # Ensure 'won' is numeric
    subset['won'] = subset['won'].astype(float)

    # === 1. Top/Bottom 10 Absolute Correlations ===
    numeric_cols = subset.select_dtypes(include='number').columns
    corr_all = subset[numeric_cols].corr()['won'].dropna()
    corr_all_abs = corr_all.drop(labels='won').abs().sort_values(ascending=False)
    top_10 = corr_all_abs.head(10).index
    bottom_10 = corr_all_abs.tail(10).index

    top_10_corr = corr_all[top_10]
    bottom_10_corr = corr_all[bottom_10]

    # === 2. Non-Combat Stats ===
    non_combat = [
        'current_win_streak', 'current_lose_streak', 'longest_win_streak',
        'wins', 'losses', 'draw', 'total_time_fought(seconds)', 'total_rounds_fought',
        'total_title_bouts', 'Reach_cms', 'Height_cms', 'Weight_lbs', 'age'
    ]
    non_combat_corr = subset[non_combat + ['won']].corr()['won'].drop('won').sort_values(ascending=False)

    # === 3. Differentials ===
    diffs = ['reach_diff', 'height_diff', 'win_streak_diff', 'age_diff']
    diff_corr = subset[diffs + ['won']].corr()['won'].drop('won').sort_values(ascending=False)

    # === 4. Stance win rates ===
    stance_counts = subset['Stance'].value_counts()
    stance_winrates = subset.groupby('Stance')['won'].mean()
    stance_summary = pd.DataFrame({'win_rate': stance_winrates, 'count': stance_counts})
    stance_summary = stance_summary[stance_summary['count'] >= 30]  # Filter rare stances

    return {
        'Top 10 Absolute Correlations': top_10_corr,
        'Bottom 10 Absolute Correlations': bottom_10_corr,
        'Non-Combat Correlations': non_combat_corr,
        'Differential Correlations': diff_corr,
        'Stance Win Rates': stance_summary
    }

# %%
lightweight_corrs = get_cleaned_correlation_summary_by_class(df_fighter_stats, 'Lightweight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 lightweight_corrs = get_cleaned_correlation_summary_by_class(df_fighter_stats, 'Lightweight')
#
# Cell In[63], line 36, in get_cleaned_correlation_summary_by_class(df, weight_class)
#      34 # === 3. Differentials ===
#      35 diffs = ['reach_diff', 'height_diff', 'win_streak_diff', 'age_diff']
# ---> 36 diff_corr = subset[diffs + ['won']].corr()['won'].drop('won').sort_values(ascending=False)
#      38 # === 4. Stance win rates ===
#      39 stance_counts = subset['Stance'].value_counts()
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['reach_diff', 'height_diff', 'win_streak_diff', 'age_diff'] not in index"

# %%
# Ensure differential columns exist in your DataFrame
df_fighter_stats['reach_diff'] = df_fighter_stats['Reach_cms']  # Placeholder if no blue fighter data
df_fighter_stats['height_diff'] = df_fighter_stats['Height_cms']
df_fighter_stats['win_streak_diff'] = df_fighter_stats['current_win_streak']
df_fighter_stats['age_diff'] = df_fighter_stats['age']

# %%
lightweight_corrs = get_cleaned_correlation_summary_by_class(df_fighter_stats, 'Lightweight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a 2x2 grid of subplots
plt.figure(figsize=(16, 12))

# 1. Top 10 Absolute Correlations
plt.subplot(2, 2, 1)
top_corr = lightweight_corrs['Top 10 Absolute Correlations']
sns.barplot(x=top_corr.values, y=top_corr.index, palette='crest')
plt.title('Top 10 Absolute Correlations with Victory')
plt.xlabel('Correlation')

# 2. Bottom 10 Absolute Correlations
plt.subplot(2, 2, 2)
bottom_corr = lightweight_corrs['Bottom 10 Absolute Correlations']
sns.barplot(x=bottom_corr.values, y=bottom_corr.index, palette='flare')
plt.title('Bottom 10 Absolute Correlations with Victory')
plt.xlabel('Correlation')

# 3. Non-Combat Correlations
plt.subplot(2, 2, 3)
non_combat = lightweight_corrs['Non-Combat Correlations'].dropna()
sns.barplot(x=non_combat.values, y=non_combat.index, palette='magma')
plt.title('Non-Combat Stat Correlations with Victory')
plt.xlabel('Correlation')

# 4. Stance Win Rates
plt.subplot(2, 2, 4)
stance_df = lightweight_corrs['Stance Win Rates'].copy()
sns.barplot(x='win_rate', y=stance_df.index, data=stance_df, palette='pastel')
plt.title('Win Rate by Stance')
plt.xlabel('Win Rate')

# Adjust layout
plt.tight_layout()

# Save to file
plt.savefig('lightweight_correlation_dashboard.png', dpi=300)
plt.show()
# Out:
# /tmp/ipykernel_22222/3148835187.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_corr.values, y=top_corr.index, palette='crest')
# /tmp/ipykernel_22222/3148835187.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=bottom_corr.values, y=bottom_corr.index, palette='flare')
# /tmp/ipykernel_22222/3148835187.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=non_combat.values, y=non_combat.index, palette='magma')
# /tmp/ipykernel_22222/3148835187.py:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='win_rate', y=stance_df.index, data=stance_df, palette='pastel')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16, 12))

# 1. Top 10 Absolute Correlations
plt.subplot(2, 2, 1)
top_corr = lightweight_corrs['Top 10 Absolute Correlations']
sns.barplot(x=top_corr.values, y=top_corr.index, hue=top_corr.index, palette='crest', legend=False)
plt.title('Top 10 Absolute Correlations with Victory')
plt.xlabel('Correlation')

# 2. Bottom 10 Absolute Correlations
plt.subplot(2, 2, 2)
bottom_corr = lightweight_corrs['Bottom 10 Absolute Correlations']
sns.barplot(x=bottom_corr.values, y=bottom_corr.index, hue=bottom_corr.index, palette='flare', legend=False)
plt.title('Bottom 10 Absolute Correlations with Victory')
plt.xlabel('Correlation')

# 3. Non-Combat Correlations
plt.subplot(2, 2, 3)
non_combat = lightweight_corrs['Non-Combat Correlations'].dropna()
sns.barplot(x=non_combat.values, y=non_combat.index, hue=non_combat.index, palette='magma', legend=False)
plt.title('Non-Combat Stat Correlations with Victory')
plt.xlabel('Correlation')

# 4. Stance Win Rates
plt.subplot(2, 2, 4)
stance_df = lightweight_corrs['Stance Win Rates'].copy()
sns.barplot(x='win_rate', y=stance_df.index, hue=stance_df.index, data=stance_df, palette='pastel', legend=False)
plt.title('Win Rate by Stance')
plt.xlabel('Win Rate')

pl
